# %%
import graphlab as gl

(data, bad) = gl.SFrame.read_csv_with_errors('./Data/yelp.csv')
data.save('./Data/yelpdata')
# Out:
# PROGRESS: Unable to parse line ""JsanjIgKkl_b6kc4qWC55Q","2010-02-02","VfYz0oG_5CbMha-n4JP6mw",4,"Hello, my name is Jeremy and I\'m an addict.... I am NEVER going to quit! My stomach is blind and loves all foods. Today, Indian! Delhi Palace is very good. I have enjoyed every dish. If you are a beginner I truly recommend a dish called Chicken Tikka Masala. It is a real starter dish and is a mainstay on almost every Indian menu. It is fragrant, creamy, rich and warming. It is not spicy. That\'s just a tip for newcomers. For foodies and ethnic eaters do try the Karahi Goat very hot. It is delicious. Vegetable Korma quells the heat a little. The Paneer here is some of the best I have tasted. Fresh, firm and creamy. Daler Mehndi the ""Punjab Pimp"" is humming beats in my head now. I must go , my food has arrived. Oh, I love when reps bring me free lunch.  Please, do not forget the Naan. I hope you enjoy.","review","S9nPKuN1OCPiP0CjlMJamQ",{"f"
# ...

# %%
yelpdata = gl.load_sframe('./Data/yelpdata')

# %%
yelpdata
# Out:
# Columns:
# 	business_id	str
# 	date	str
# 	review_id	str
# 	stars	int
# 	text	str
# 	type	str
# 	user_id	str
# 	votes	dict
# 	year	int
# 	month	int
# 	day	int
# 	categories	list
# 	city	str
# 	full_address	str
# 	latitude	float
# 	longitude	float
# 	name	str
# 	open	int
# 	business_review_count	int
# 	business_avg_stars	float
# 	state	str
# 	business_type	str
# 	user_avg_stars	float
# 	user_name	str
# 	user_review_count	int
# 	user_type	str
# 	votes_funny	int
# 	votes_cool	int
# 	votes_useful	int
# 	categories_dict	dict
#
# Rows: 25442
#
# Data:
# +------------------------+------------+------------------------+-------+
# |      business_id       |    date    |       review_id        | stars |
# +------------------------+------------+------------------------+-------+
# | 9yKzy9PApeiPPOUJEtnvkg | 2011-01-26 | fWKvX83p0-ka4JS3dc6E5A |   5   |
# | ZRJwVLyzEJq1VAihDhYiow | 2011-07-27 | IjZ33sJrzXqU-0X6U8NwyA |   5   |
# ...
